# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('adult.csv')
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df = df.apply(lambda x: x.replace('?', 'None'))
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90      None   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66      None  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.drop_duplicates(keep = False, inplace = True)
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90      None   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66      None  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32514 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32514 non-null  int64
#  1   workclass       32514 non-null  object
#  2   fnlwgt          32514 non-null  int64
#  3   education       32514 non-null  object
#  4   education.num   32514 non-null  int64
#  5   marital.status  32514 non-null  object
#  6   occupation      32514 non-null  object
#  7   relationship    32514 non-null  object
#  8   race            32514 non-null  object
#  9   sex             32514 non-null  object
#  10  capital.gain    32514 non-null  int64
#  11  capital.loss    32514 non-null  int64
#  12  hours.per.week  32514 non-null  int64
#  13  native.country  32514 non-null  object
#  14  income          32514 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 4.0+ MB

# %%
df['Hours per week'] = df['hours.per.week']
df['Native country'] = df['native.country']
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90      None   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66      None  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
df['capital gain'] = df['capital.gain']
df['capital loss'] = df['capital.loss']
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90      None   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66      None  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
df1 = df.groupby(['sex', 'income']) ['hours.per.week'].count().to_frame().sort_values(by = 'sex', ascending = True)
df1
# Out:
#                hours.per.week
# sex    income
# Female <=50K             9575
#        >50K              1179
# Male   <=50K            15102
#        >50K              6658

# %%
df1.plot(kind = 'bar' )
plt.xlabel('Sex', color = 'red', size = 15)
plt.ylabel('Hours per week', color = 'green', size = 15)
plt.title('Sex with the highest number worked per hours per week')
plt.show()

# %%
lesser_income = []

for i in df['income']:
    if i == '<=50K':
        lesser_income.append(i)
    else:
        lesser_income.append(None)

df['Lesser income'] = lesser_income
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90      None   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66      None  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
higher_income = []
for i in df['income']:
    if i == '>50K':
        higher_income.append(i)
    else:
        higher_income.append(None)

df['Higher Income'] = higher_income
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90      None   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66      None  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
# Get the Education degree with the highest capital gain while msking Lesser income

df2 = df.groupby(['education', 'Lesser income']) ['capital gain'].sum().to_frame().sort_values(by = 'capital gain', ascending = True)
df2
# Out:
#                             capital gain
# education    Lesser income
# 1st-4th      <=50K                 13459
# Doctorate    <=50K                 23592
# Prof-school  <=50K                 28604
# 5th-6th      <=50K                 31543
# 12th         <=50K                 31630
# Preschool    <=50K                 45818
# 9th          <=50K                 65479
# Assoc-acdm   <=50K                 88532
# 11th         <=50K                 95653
# 7th-8th      <=50K                105132
# 10th         <=50K                117720
# Assoc-voc    <=50K                200959
# Masters      <=50K                218332
# Bachelors    <=50K                510534
# Some-college <=50K                742042
# HS-grad      <=50K               1358132

# %%
df2.plot(kind = 'bar', color = 'green')
plt.xlabel('Education', size = 6)
plt.ylabel('Capital Gain', size = 6)
plt.title("Education degree making lesser income with the highest Capital Gain")
plt.plot()
# Out:
# []

# %%
df3 = df.groupby(['education', 'Higher Income']) ['capital gain'].sum().to_frame().sort_values(by = 'capital gain', ascending = True)
df3
# Out:
#                             capital gain
# education    Higher Income
# 1st-4th      >50K                   7688
# 5th-6th      >50K                  27072
# 7th-8th      >50K                  45993
# 12th         >50K                  91380
# 9th          >50K                 110355
# 11th         >50K                 157087
# 10th         >50K                 259748
# Assoc-acdm   >50K                 594774
# Assoc-voc    >50K                 787242
# Doctorate    >50K                1946478
# Some-college >50K                3623985
# Masters      >50K                4196965
# HS-grad      >50K                4698846
# Prof-school  >50K                5970100
# Bachelors    >50K                8894450

# %%
df3.plot(kind = 'bar', color = 'red')
plt.xlabel('Education', size = 6)
plt.ylabel('Capital Gain', size = 6)
plt.title("Education degree making higher income with the highest Capital Gain")
plt.plot()
# Out:
# []

# %%
df4 = df.groupby(['education', 'race']) ['Lesser income'].count().to_frame().sort_values(by = 'Lesser income', ascending = True)
df4.head(30)
# Out:
#                                 Lesser income
# education   race
# Prof-school Amer-Indian-Eskimo              0
#             Other                           0
# Doctorate   Amer-Indian-Eskimo              1
#             Other                           1
# Preschool   Other                           2
# Doctorate   Black                           2
# 5th-6th     Amer-Indian-Eskimo              2
# Masters     Amer-Indian-Eskimo              2
# 1st-4th     Amer-Indian-Eskimo              4
# Masters     Other                           5
# 12th        Amer-Indian-Eskimo              5
# Preschool   Black                           5
# 9th         Amer-Indian-Eskimo              5
# 1st-4th     Asian-Pac-Islander              5
# Preschool   Asian-Pac-Islander              6
# Assoc-voc   Other                           6
# Assoc-acdm  Other                           6
#             Amer-Indian-Eskimo              7
# Prof-school Black                           7
# ...

# %%
df4.head(20).plot(kind = 'bar', color = 'orange')
plt.xlabel('Education', size = 6)
plt.ylabel('Lesser income', size = 6)
plt.title("Race with the highest number earning lesser income")
plt.plot()
# Out:
# []
